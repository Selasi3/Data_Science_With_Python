# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pokemon = pd.read_csv("../dataset/pokemon.csv")

# %%
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
pokemon.tail()
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 802  803      poipole              7     0.6     1.8              189
# 803  804    naganadel              7     3.6   150.0              243
# 804  805    stakataka              7     5.5   820.0              257
# 805  806  blacephalon              7     1.8    13.0              257
# 806  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# 802    poison     NaN  67      73       67     73              73
# 803    poison  dragon  73      73       73    121             127
# 804      rock   steel  61     131      211     13              53
# 805      fire   ghost  53     127       53    107             151
# 806  electric     NaN  88     112       75    143             102
#
#      special-defense
# 802               67
# 803               73
# 804              101
# 805               79
# 806               80

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 807 entries, 0 to 806
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               807 non-null    int64
#  1   species          807 non-null    object
#  2   generation_id    807 non-null    int64
#  3   height           807 non-null    float64
#  4   weight           807 non-null    float64
#  5   base_experience  807 non-null    int64
#  6   type_1           807 non-null    object
#  7   type_2           405 non-null    object
#  8   hp               807 non-null    int64
#  9   attack           807 non-null    int64
#  10  defense          807 non-null    int64
#  11  speed            807 non-null    int64
#  12  special-attack   807 non-null    int64
#  13  special-defense  807 non-null    int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 88.4+ KB

# %% [markdown]
# #### Histogram

# %%
sns.histplot(pokemon["height"], bins =10)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %%
sns.histplot(pokemon["weight"], bins=10)
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sns.histplot(pokemon["weight"], bins=10)
plt.title("Histogram of Weight")
plt.show()

# %% [markdown]
# ### Swarmplot

# %%
sns.swarmplot(y= pokemon['weight'])
plt.show()
# Out:
# C:\Users\Blossom Academy\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(y= pokemon['height'])
plt.show()
# Out:
# C:\Users\Blossom Academy\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 48.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ###  Strip plot

# %%
sns.stripplot(y= pokemon['weight'])
plt.show()

# %%
sns.stripplot(y= pokemon['height'])
plt.show()

# %% [markdown]
# ### Kernel Density Plot

# %%
sns.kdeplot(pokemon["weight"])
plt.title("Histogram of Weight")
plt.show()

# %%
sns.kdeplot(pokemon["height"])
plt.title("Histogram of Height")
plt.show()

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x=pokemon["special-defense"])
# Out:
# <Axes: xlabel='special-defense'>

# %%
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
# Plotting boxplot for  categorical and numerical variable
plt.figure(figsize=(10,8))
sns.boxplot(x='type_1',y='weight',data = pokemon )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### CountPlot

# %%
pokemon["type_1"].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
pokemon["type_1"].nunique()
# Out:
# 18

# %%
sns.countplot(y=pokemon['type_2'])
plt.show()

# %%
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
pokemon.generation_id.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7], dtype=int64)

# %%
tips = pd.read_csv("../dataset/tips_data.csv")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# ### Scatter Plot

# %%
# creating a scatterplot with a low level function - sactterplot() 

sns.scatterplot(x='total_bill',y='tip',data = tips)
plt.show()

# %% [markdown]
# ### Relational  Plot

# %%
sns.relplot(x='total_bill',y = 'tip',data = tips,kind = 'scatter')
plt.show()

# %%
# Specifying rows for subplots

sns.relplot(x='total_bill',y = 'tip',data = tips,
            kind = 'scatter',
           row ='sex' )
plt.show()

# %%
# Specifying columns for subplots

sns.relplot(x='total_bill',y = 'tip',data = tips,
            kind = 'scatter',
            col ='day'
           )
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y = 'tip',data = tips,
            kind = 'scatter',
           size = 'size')
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill',y = 'tip',data = tips,
            kind = 'scatter',
           size = 'size',
           hue = 'size')
plt.show()

# %%
sns.relplot(x='total_bill',y = 'tip',data = tips,
            kind = 'scatter',
           hue = 'smoker',
           style= 'smoker')
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxenplot(x="sex",
               y="size", 
               data=tips,
              palette='coolwarm')
# Out:
# <Axes: xlabel='sex', ylabel='size'>

# %%
sns.catplot(x="sex",data=tips,kind='count')
plt.xticks(rotation =45)


# Show plot
plt.show()
